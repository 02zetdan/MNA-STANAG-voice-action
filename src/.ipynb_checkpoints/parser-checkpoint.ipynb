# %%
# parser 1
from scapy.all import rdpcap, UDP
import pynmea2
import json

def load_pcap(filepath):
    """Extract raw NMEA sentences from a pcap file."""
    packets = rdpcap(filepath)
    sentences = []

    for packet in packets:
        if UDP in packet:
            try:
                payload = bytes(packet[UDP].payload).decode("ascii").strip()
                if payload.startswith("$"):
                    sentences.append(payload)
            except UnicodeDecodeError:
                pass

    return sentences


def parse_sentence(raw):
    try:
        return pynmea2.parse(raw)
    except pynmea2.ParseError as e:
        print(f"[WARN] Could not parse: {raw!r} — {e}")
        return None


def assess_quality(rmc):
    if rmc.status == "V":
        return 0.0
    score = 1.0
    hdop = getattr(rmc, "horizontal_dil", None)
    if hdop:
        hdop = float(hdop)
        if hdop > 2.0:
            score -= 0.3
        elif hdop > 1.0:
            score -= 0.1
    return round(score, 2)


def build_track(rmc, hdt=None):
    confidence = assess_quality(rmc)
    return {
        "trackId":   f"TRK-{rmc.timestamp}",
        "type":      "SURFACE",
        "source":    "NMEA_GNSS",
        "timestamp": rmc.datetime.isoformat() if rmc.datetime else None,
        "position": {
            "lat": rmc.latitude  if rmc.lat  else None,
            "lon": rmc.longitude if rmc.lon  else None,
        },
        "velocity": {
            "speedKnots":       float(rmc.spd_over_grnd) if rmc.spd_over_grnd else None,
            "courseOverGround": float(rmc.true_course)   if rmc.true_course   else None,
            "trueHeading":      float(hdt.heading)       if hdt               else None,
        },
        "pntConfidence": confidence,
        "gnssStatus":    rmc.status,
    }


def process_pcap(filepath):
    sentences = load_pcap(filepath)
    print(f"✓ Extracted {len(sentences)} NMEA sentences from pcap\n")

    tracks = []
    last_hdt = None

    for raw in sentences:
        msg = parse_sentence(raw)
        if msg is None:
            continue

        if isinstance(msg, pynmea2.HDT):
            last_hdt = msg

        elif isinstance(msg, pynmea2.RMC):
            track = build_track(msg, hdt=last_hdt)
            tracks.append(track)
            print(json.dumps(track, indent=2, default=str))

    return tracks


if __name__ == "__main__":
    results = process_pcap("kraken_data/multicast_AdvNavData-2026-05-08_07-40-14_capture.pcap")
    print(f"\n✓ Processed {len(results)} track updates")

# %%
#parser 2 with writing to file
# parser 1
from scapy.all import rdpcap, UDP
import pynmea2
import json

def load_pcap(filepath):
    """Extract raw NMEA sentences from a pcap file."""
    packets = rdpcap(filepath)
    sentences = []

    for packet in packets:
        if UDP in packet:
            try:
                payload = bytes(packet[UDP].payload).decode("ascii").strip()
                if payload.startswith("$"):
                    sentences.append(payload)
            except UnicodeDecodeError:
                pass

    return sentences


def parse_sentence(raw):
    try:
        return pynmea2.parse(raw)
    except pynmea2.ParseError as e:
        print(f"[WARN] Could not parse: {raw!r} — {e}")
        return None


def assess_quality(rmc):
    if rmc.status == "V":
        return 0.0
    score = 1.0
    hdop = getattr(rmc, "horizontal_dil", None)
    if hdop:
        hdop = float(hdop)
        if hdop > 2.0:
            score -= 0.3
        elif hdop > 1.0:
            score -= 0.1
    return round(score, 2)


def build_track(rmc, hdt=None):
    confidence = assess_quality(rmc)
    return {
        "trackId":   f"TRK-{rmc.timestamp}",
        "sentenceType":  "RMC+HDT" if hdt else "RMC",
        "type":      "SURFACE",
        "source":    "NMEA_GNSS",
        "timestamp": rmc.datetime.isoformat() if rmc.datetime else None,
        "position": {
            "lat": rmc.latitude  if rmc.lat  else None,
            "lon": rmc.longitude if rmc.lon  else None,
        },
        "velocity": {
            "speedKnots":       float(rmc.spd_over_grnd) if rmc.spd_over_grnd else None,
            "courseOverGround": float(rmc.true_course)   if rmc.true_course   else None,
            "trueHeading":      float(hdt.heading)       if hdt               else None,
        },
        "pntConfidence": confidence,
        "gnssStatus":    rmc.status,
    }


def process_pcap(filepath, output_file="tracks_output.json", max_sentences=1000):
    sentences = load_pcap(filepath, max_sentences=max_sentences)
    print(f"✓ Extracted {len(sentences)} NMEA sentences (capped at {max_sentences})\n")
    tracks = []
    last_hdt = None
    for raw in sentences:
        msg = parse_sentence(raw)
        if msg is None:
            continue
        if isinstance(msg, pynmea2.HDT):
            last_hdt = msg
        elif isinstance(msg, pynmea2.RMC):
            track = build_track(msg, hdt=last_hdt)
            tracks.append(track)

    with open(output_file, "w") as f:
        json.dump(tracks, f, indent=2, default=str)

    print(f"✓ Processed {len(tracks)} track updates")
    print(f"✓ Results written to {output_file}")
    return tracks

def load_pcap(filepath, max_sentences=1000):
    packets = rdpcap(filepath)
    sentences = []
    for packet in packets:
        if len(sentences) >= max_sentences:
            break
        if UDP in packet:
            try:
                payload = bytes(packet[UDP].payload).decode("ascii").strip()
                if payload.startswith("$"):
                    sentences.append(payload)
            except UnicodeDecodeError:
                pass
    return sentences


if __name__ == "__main__":
    results = process_pcap("kraken_data/multicast_AdvNavData-2026-05-08_07-40-14_capture.pcap")
    print(f"\n✓ Processed {len(results)} track updates")
# Out:
# ✓ Extracted 673843 NMEA sentences from pcap
#
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDM,,*56\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00' — ('could not parse data', '$GPHDT,,*4F\r\n\x00\x00\x00\x00\x00')
# [WARN] Could not parse: '$GPHDT,0.0,T*35\r\n\x00' — ('could not parse data', '$GPHDT,0.0,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.3,T*36\r\n\x00' — ('could not parse data', '$GPHDT,0.3,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.7,T*32\r\n\x00' — ('could not parse data', '$GPHDT,0.7,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.9,T*3C\r\n\x00' — ('could not parse data', '$GPHDT,0.9,T*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.2,T*36\r\n\x00' — ('could not parse data', '$GPHDT,1.2,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.5,T*31\r\n\x00' — ('could not parse data', '$GPHDT,1.5,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.8,T*3C\r\n\x00' — ('could not parse data', '$GPHDT,1.8,T*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.0,T*37\r\n\x00' — ('could not parse data', '$GPHDT,2.0,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.3,T*34\r\n\x00' — ('could not parse data', '$GPHDT,2.3,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.5,T*32\r\n\x00' — ('could not parse data', '$GPHDT,2.5,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.8,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,2.8,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.0,T*36\r\n\x00' — ('could not parse data', '$GPHDT,3.0,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.3,T*35\r\n\x00' — ('could not parse data', '$GPHDT,3.3,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.5,T*33\r\n\x00' — ('could not parse data', '$GPHDT,3.5,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.7,T*31\r\n\x00' — ('could not parse data', '$GPHDT,3.7,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.9,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,3.9,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.1,T*30\r\n\x00' — ('could not parse data', '$GPHDT,4.1,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.2,T*33\r\n\x00' — ('could not parse data', '$GPHDT,4.2,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.4,T*35\r\n\x00' — ('could not parse data', '$GPHDT,4.4,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.6,T*37\r\n\x00' — ('could not parse data', '$GPHDT,4.6,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.7,T*36\r\n\x00' — ('could not parse data', '$GPHDT,4.7,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.9,T*38\r\n\x00' — ('could not parse data', '$GPHDT,4.9,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.0,T*30\r\n\x00' — ('could not parse data', '$GPHDT,5.0,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.1,T*31\r\n\x00' — ('could not parse data', '$GPHDT,5.1,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.2,T*32\r\n\x00' — ('could not parse data', '$GPHDT,5.2,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.3,T*33\r\n\x00' — ('could not parse data', '$GPHDT,5.3,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.4,T*34\r\n\x00' — ('could not parse data', '$GPHDT,5.4,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.5,T*35\r\n\x00' — ('could not parse data', '$GPHDT,5.5,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.6,T*36\r\n\x00' — ('could not parse data', '$GPHDT,5.6,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.7,T*37\r\n\x00' — ('could not parse data', '$GPHDT,5.7,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.8,T*38\r\n\x00' — ('could not parse data', '$GPHDT,5.8,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.8,T*38\r\n\x00' — ('could not parse data', '$GPHDT,5.8,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.9,T*39\r\n\x00' — ('could not parse data', '$GPHDT,5.9,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.9,T*39\r\n\x00' — ('could not parse data', '$GPHDT,5.9,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.9,T*39\r\n\x00' — ('could not parse data', '$GPHDT,5.9,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.0,T*33\r\n\x00' — ('could not parse data', '$GPHDT,6.0,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.0,T*33\r\n\x00' — ('could not parse data', '$GPHDT,6.0,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.0,T*33\r\n\x00' — ('could not parse data', '$GPHDT,6.0,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.0,T*33\r\n\x00' — ('could not parse data', '$GPHDT,6.0,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.0,T*33\r\n\x00' — ('could not parse data', '$GPHDT,6.0,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.9,T*39\r\n\x00' — ('could not parse data', '$GPHDT,5.9,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.9,T*39\r\n\x00' — ('could not parse data', '$GPHDT,5.9,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.8,T*38\r\n\x00' — ('could not parse data', '$GPHDT,5.8,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.8,T*38\r\n\x00' — ('could not parse data', '$GPHDT,5.8,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.7,T*37\r\n\x00' — ('could not parse data', '$GPHDT,5.7,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.6,T*36\r\n\x00' — ('could not parse data', '$GPHDT,5.6,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.5,T*35\r\n\x00' — ('could not parse data', '$GPHDT,5.5,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.4,T*34\r\n\x00' — ('could not parse data', '$GPHDT,5.4,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.3,T*33\r\n\x00' — ('could not parse data', '$GPHDT,5.3,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.2,T*32\r\n\x00' — ('could not parse data', '$GPHDT,5.2,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.1,T*31\r\n\x00' — ('could not parse data', '$GPHDT,5.1,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.9,T*38\r\n\x00' — ('could not parse data', '$GPHDT,4.9,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.8,T*39\r\n\x00' — ('could not parse data', '$GPHDT,4.8,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.6,T*37\r\n\x00' — ('could not parse data', '$GPHDT,4.6,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.5,T*34\r\n\x00' — ('could not parse data', '$GPHDT,4.5,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.3,T*32\r\n\x00' — ('could not parse data', '$GPHDT,4.3,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.1,T*30\r\n\x00' — ('could not parse data', '$GPHDT,4.1,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.9,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,3.9,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.8,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,3.8,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.5,T*33\r\n\x00' — ('could not parse data', '$GPHDT,3.5,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.3,T*35\r\n\x00' — ('could not parse data', '$GPHDT,3.3,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.1,T*37\r\n\x00' — ('could not parse data', '$GPHDT,3.1,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.8,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,2.8,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.6,T*31\r\n\x00' — ('could not parse data', '$GPHDT,2.6,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.3,T*34\r\n\x00' — ('could not parse data', '$GPHDT,2.3,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.0,T*37\r\n\x00' — ('could not parse data', '$GPHDT,2.0,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.7,T*33\r\n\x00' — ('could not parse data', '$GPHDT,1.7,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.5,T*31\r\n\x00' — ('could not parse data', '$GPHDT,1.5,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.2,T*36\r\n\x00' — ('could not parse data', '$GPHDT,1.2,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.8,T*3D\r\n\x00' — ('could not parse data', '$GPHDT,0.8,T*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.5,T*30\r\n\x00' — ('could not parse data', '$GPHDT,0.5,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.2,T*37\r\n\x00' — ('could not parse data', '$GPHDT,0.2,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.2,T*37\r\n\x00' — ('could not parse data', '$GPHDT,0.2,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.6,T*33\r\n\x00' — ('could not parse data', '$GPHDT,0.6,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.9,T*3C\r\n\x00' — ('could not parse data', '$GPHDT,0.9,T*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.2,T*36\r\n\x00' — ('could not parse data', '$GPHDT,1.2,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.5,T*31\r\n\x00' — ('could not parse data', '$GPHDT,1.5,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.8,T*3C\r\n\x00' — ('could not parse data', '$GPHDT,1.8,T*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.1,T*36\r\n\x00' — ('could not parse data', '$GPHDT,2.1,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.5,T*32\r\n\x00' — ('could not parse data', '$GPHDT,2.5,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.8,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,2.8,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.1,T*37\r\n\x00' — ('could not parse data', '$GPHDT,3.1,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.4,T*32\r\n\x00' — ('could not parse data', '$GPHDT,3.4,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.7,T*31\r\n\x00' — ('could not parse data', '$GPHDT,3.7,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.0,T*31\r\n\x00' — ('could not parse data', '$GPHDT,4.0,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.2,T*33\r\n\x00' — ('could not parse data', '$GPHDT,4.2,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.5,T*34\r\n\x00' — ('could not parse data', '$GPHDT,4.5,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.8,T*39\r\n\x00' — ('could not parse data', '$GPHDT,4.8,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.0,T*30\r\n\x00' — ('could not parse data', '$GPHDT,5.0,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.3,T*33\r\n\x00' — ('could not parse data', '$GPHDT,5.3,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.6,T*36\r\n\x00' — ('could not parse data', '$GPHDT,5.6,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.8,T*38\r\n\x00' — ('could not parse data', '$GPHDT,5.8,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.0,T*33\r\n\x00' — ('could not parse data', '$GPHDT,6.0,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.3,T*30\r\n\x00' — ('could not parse data', '$GPHDT,6.3,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.4,T*37\r\n\x00' — ('could not parse data', '$GPHDT,6.4,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.6,T*35\r\n\x00' — ('could not parse data', '$GPHDT,6.6,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,0.4,M*31\r\n\x00' — ('could not parse data', '$GPHDM,0.4,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.8,T*3B\r\n\x00' — ('could not parse data', '$GPHDT,6.8,T*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.0,T*32\r\n\x00' — ('could not parse data', '$GPHDT,7.0,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.2,T*30\r\n\x00' — ('could not parse data', '$GPHDT,7.2,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,0.8,M*3D\r\n\x00' — ('could not parse data', '$GPHDM,0.8,M*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.4,T*36\r\n\x00' — ('could not parse data', '$GPHDT,7.4,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.6,T*34\r\n\x00' — ('could not parse data', '$GPHDT,7.6,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,1.3,M*37\r\n\x00' — ('could not parse data', '$GPHDM,1.3,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.8,T*3A\r\n\x00' — ('could not parse data', '$GPHDT,7.8,T*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.9,T*3B\r\n\x00' — ('could not parse data', '$GPHDT,7.9,T*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.1,T*3C\r\n\x00' — ('could not parse data', '$GPHDT,8.1,T*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDM,1.7,M*33\r\n\x00' — ('could not parse data', '$GPHDM,1.7,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.3,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,8.3,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.4,T*39\r\n\x00' — ('could not parse data', '$GPHDT,8.4,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDM,2.1,M*36\r\n\x00' — ('could not parse data', '$GPHDM,2.1,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.6,T*3B\r\n\x00' — ('could not parse data', '$GPHDT,8.6,T*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.7,T*3A\r\n\x00' — ('could not parse data', '$GPHDT,8.7,T*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.9,T*34\r\n\x00' — ('could not parse data', '$GPHDT,8.9,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,2.5,M*32\r\n\x00' — ('could not parse data', '$GPHDM,2.5,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.0,T*3C\r\n\x00' — ('could not parse data', '$GPHDT,9.0,T*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.2,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,9.2,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDM,2.8,M*3F\r\n\x00' — ('could not parse data', '$GPHDM,2.8,M*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.3,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,9.3,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.4,T*38\r\n\x00' — ('could not parse data', '$GPHDT,9.4,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.5,T*39\r\n\x00' — ('could not parse data', '$GPHDT,9.5,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.1,M*37\r\n\x00' — ('could not parse data', '$GPHDM,3.1,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.6,T*3A\r\n\x00' — ('could not parse data', '$GPHDT,9.6,T*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.7,T*3B\r\n\x00' — ('could not parse data', '$GPHDT,9.7,T*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.4,M*32\r\n\x00' — ('could not parse data', '$GPHDM,3.4,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.8,T*34\r\n\x00' — ('could not parse data', '$GPHDT,9.8,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.9,T*35\r\n\x00' — ('could not parse data', '$GPHDT,9.9,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.6,M*30\r\n\x00' — ('could not parse data', '$GPHDM,3.6,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.8,M*3E\r\n\x00' — ('could not parse data', '$GPHDM,3.8,M*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.9,M*3F\r\n\x00' — ('could not parse data', '$GPHDM,3.9,M*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.0,M*31\r\n\x00' — ('could not parse data', '$GPHDM,4.0,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.1,M*30\r\n\x00' — ('could not parse data', '$GPHDM,4.1,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.2,M*33\r\n\x00' — ('could not parse data', '$GPHDM,4.2,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.2,M*33\r\n\x00' — ('could not parse data', '$GPHDM,4.2,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.3,M*32\r\n\x00' — ('could not parse data', '$GPHDM,4.3,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.3,M*32\r\n\x00' — ('could not parse data', '$GPHDM,4.3,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.4,M*35\r\n\x00' — ('could not parse data', '$GPHDM,4.4,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.4,M*35\r\n\x00' — ('could not parse data', '$GPHDM,4.4,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.4,M*35\r\n\x00' — ('could not parse data', '$GPHDM,4.4,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.4,M*35\r\n\x00' — ('could not parse data', '$GPHDM,4.4,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.3,M*32\r\n\x00' — ('could not parse data', '$GPHDM,4.3,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.2,M*33\r\n\x00' — ('could not parse data', '$GPHDM,4.2,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.1,M*30\r\n\x00' — ('could not parse data', '$GPHDM,4.1,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.0,M*31\r\n\x00' — ('could not parse data', '$GPHDM,4.0,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.8,M*3E\r\n\x00' — ('could not parse data', '$GPHDM,3.8,M*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.6,M*30\r\n\x00' — ('could not parse data', '$GPHDM,3.6,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.9,T*35\r\n\x00' — ('could not parse data', '$GPHDT,9.9,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.8,T*34\r\n\x00' — ('could not parse data', '$GPHDT,9.8,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.4,M*32\r\n\x00' — ('could not parse data', '$GPHDM,3.4,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.8,T*34\r\n\x00' — ('could not parse data', '$GPHDT,9.8,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.7,T*3B\r\n\x00' — ('could not parse data', '$GPHDT,9.7,T*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.6,T*3A\r\n\x00' — ('could not parse data', '$GPHDT,9.6,T*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.2,M*34\r\n\x00' — ('could not parse data', '$GPHDM,3.2,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.5,T*39\r\n\x00' — ('could not parse data', '$GPHDT,9.5,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.4,T*38\r\n\x00' — ('could not parse data', '$GPHDT,9.4,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.0,M*36\r\n\x00' — ('could not parse data', '$GPHDM,3.0,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.3,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,9.3,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.2,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,9.2,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.1,T*3D\r\n\x00' — ('could not parse data', '$GPHDT,9.1,T*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDM,2.8,M*3F\r\n\x00' — ('could not parse data', '$GPHDM,2.8,M*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.1,T*3D\r\n\x00' — ('could not parse data', '$GPHDT,9.1,T*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.0,T*3C\r\n\x00' — ('could not parse data', '$GPHDT,9.0,T*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDM,2.5,M*32\r\n\x00' — ('could not parse data', '$GPHDM,2.5,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.9,T*34\r\n\x00' — ('could not parse data', '$GPHDT,8.9,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.8,T*35\r\n\x00' — ('could not parse data', '$GPHDT,8.8,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.7,T*3A\r\n\x00' — ('could not parse data', '$GPHDT,8.7,T*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,2.3,M*34\r\n\x00' — ('could not parse data', '$GPHDM,2.3,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.6,T*3B\r\n\x00' — ('could not parse data', '$GPHDT,8.6,T*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.6,T*3B\r\n\x00' — ('could not parse data', '$GPHDT,8.6,T*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,2.1,M*36\r\n\x00' — ('could not parse data', '$GPHDM,2.1,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.5,T*38\r\n\x00' — ('could not parse data', '$GPHDT,8.5,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.4,T*39\r\n\x00' — ('could not parse data', '$GPHDT,8.4,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.3,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,8.3,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDM,2.0,M*37\r\n\x00' — ('could not parse data', '$GPHDM,2.0,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.3,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,8.3,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.2,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,8.2,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDM,1.8,M*3C\r\n\x00' — ('could not parse data', '$GPHDM,1.8,M*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.2,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,8.2,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.1,T*3C\r\n\x00' — ('could not parse data', '$GPHDT,8.1,T*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.0,T*3D\r\n\x00' — ('could not parse data', '$GPHDT,8.0,T*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDM,1.7,M*33\r\n\x00' — ('could not parse data', '$GPHDM,1.7,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.0,T*3D\r\n\x00' — ('could not parse data', '$GPHDT,8.0,T*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.9,T*3B\r\n\x00' — ('could not parse data', '$GPHDT,7.9,T*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,1.5,M*31\r\n\x00' — ('could not parse data', '$GPHDM,1.5,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.9,T*3B\r\n\x00' — ('could not parse data', '$GPHDT,7.9,T*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.8,T*3A\r\n\x00' — ('could not parse data', '$GPHDT,7.8,T*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.7,T*35\r\n\x00' — ('could not parse data', '$GPHDT,7.7,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,1.4,M*30\r\n\x00' — ('could not parse data', '$GPHDM,1.4,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.7,T*35\r\n\x00' — ('could not parse data', '$GPHDT,7.7,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.6,T*34\r\n\x00' — ('could not parse data', '$GPHDT,7.6,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,1.2,M*36\r\n\x00' — ('could not parse data', '$GPHDM,1.2,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.5,T*37\r\n\x00' — ('could not parse data', '$GPHDT,7.5,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.5,T*37\r\n\x00' — ('could not parse data', '$GPHDT,7.5,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.4,T*36\r\n\x00' — ('could not parse data', '$GPHDT,7.4,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,1.0,M*34\r\n\x00' — ('could not parse data', '$GPHDM,1.0,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.3,T*31\r\n\x00' — ('could not parse data', '$GPHDT,7.3,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.2,T*30\r\n\x00' — ('could not parse data', '$GPHDT,7.2,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,0.8,M*3D\r\n\x00' — ('could not parse data', '$GPHDM,0.8,M*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.1,T*33\r\n\x00' — ('could not parse data', '$GPHDT,7.1,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.1,T*33\r\n\x00' — ('could not parse data', '$GPHDT,7.1,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.0,T*32\r\n\x00' — ('could not parse data', '$GPHDT,7.0,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,0.6,M*33\r\n\x00' — ('could not parse data', '$GPHDM,0.6,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.9,T*3A\r\n\x00' — ('could not parse data', '$GPHDT,6.9,T*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.8,T*3B\r\n\x00' — ('could not parse data', '$GPHDT,6.8,T*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,0.4,M*31\r\n\x00' — ('could not parse data', '$GPHDM,0.4,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.7,T*34\r\n\x00' — ('could not parse data', '$GPHDT,6.7,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.6,T*35\r\n\x00' — ('could not parse data', '$GPHDT,6.6,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.5,T*36\r\n\x00' — ('could not parse data', '$GPHDT,6.5,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,0.1,M*34\r\n\x00' — ('could not parse data', '$GPHDM,0.1,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.4,T*37\r\n\x00' — ('could not parse data', '$GPHDT,6.4,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.3,T*30\r\n\x00' — ('could not parse data', '$GPHDT,6.3,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.2,T*31\r\n\x00' — ('could not parse data', '$GPHDT,6.2,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.1,T*32\r\n\x00' — ('could not parse data', '$GPHDT,6.1,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.0,T*33\r\n\x00' — ('could not parse data', '$GPHDT,6.0,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.9,T*39\r\n\x00' — ('could not parse data', '$GPHDT,5.9,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.8,T*38\r\n\x00' — ('could not parse data', '$GPHDT,5.8,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.6,T*36\r\n\x00' — ('could not parse data', '$GPHDT,5.6,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.5,T*35\r\n\x00' — ('could not parse data', '$GPHDT,5.5,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.4,T*34\r\n\x00' — ('could not parse data', '$GPHDT,5.4,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.3,T*33\r\n\x00' — ('could not parse data', '$GPHDT,5.3,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.2,T*32\r\n\x00' — ('could not parse data', '$GPHDT,5.2,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.1,T*31\r\n\x00' — ('could not parse data', '$GPHDT,5.1,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.0,T*30\r\n\x00' — ('could not parse data', '$GPHDT,5.0,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.9,T*38\r\n\x00' — ('could not parse data', '$GPHDT,4.9,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.8,T*39\r\n\x00' — ('could not parse data', '$GPHDT,4.8,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.7,T*36\r\n\x00' — ('could not parse data', '$GPHDT,4.7,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.5,T*34\r\n\x00' — ('could not parse data', '$GPHDT,4.5,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.4,T*35\r\n\x00' — ('could not parse data', '$GPHDT,4.4,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.3,T*32\r\n\x00' — ('could not parse data', '$GPHDT,4.3,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.2,T*33\r\n\x00' — ('could not parse data', '$GPHDT,4.2,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.1,T*30\r\n\x00' — ('could not parse data', '$GPHDT,4.1,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.0,T*31\r\n\x00' — ('could not parse data', '$GPHDT,4.0,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.9,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,3.9,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.8,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,3.8,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.7,T*31\r\n\x00' — ('could not parse data', '$GPHDT,3.7,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.6,T*30\r\n\x00' — ('could not parse data', '$GPHDT,3.6,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.5,T*33\r\n\x00' — ('could not parse data', '$GPHDT,3.5,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.4,T*32\r\n\x00' — ('could not parse data', '$GPHDT,3.4,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.3,T*35\r\n\x00' — ('could not parse data', '$GPHDT,3.3,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.2,T*34\r\n\x00' — ('could not parse data', '$GPHDT,3.2,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.1,T*37\r\n\x00' — ('could not parse data', '$GPHDT,3.1,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.0,T*36\r\n\x00' — ('could not parse data', '$GPHDT,3.0,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.9,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,2.9,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.8,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,2.8,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.7,T*30\r\n\x00' — ('could not parse data', '$GPHDT,2.7,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.6,T*31\r\n\x00' — ('could not parse data', '$GPHDT,2.6,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.5,T*32\r\n\x00' — ('could not parse data', '$GPHDT,2.5,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.4,T*33\r\n\x00' — ('could not parse data', '$GPHDT,2.4,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.2,T*35\r\n\x00' — ('could not parse data', '$GPHDT,2.2,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.1,T*36\r\n\x00' — ('could not parse data', '$GPHDT,2.1,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.0,T*37\r\n\x00' — ('could not parse data', '$GPHDT,2.0,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.9,T*3D\r\n\x00' — ('could not parse data', '$GPHDT,1.9,T*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.8,T*3C\r\n\x00' — ('could not parse data', '$GPHDT,1.8,T*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.7,T*33\r\n\x00' — ('could not parse data', '$GPHDT,1.7,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.5,T*31\r\n\x00' — ('could not parse data', '$GPHDT,1.5,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.4,T*30\r\n\x00' — ('could not parse data', '$GPHDT,1.4,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.4,T*30\r\n\x00' — ('could not parse data', '$GPHDT,1.4,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.2,T*36\r\n\x00' — ('could not parse data', '$GPHDT,1.2,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.1,T*35\r\n\x00' — ('could not parse data', '$GPHDT,1.1,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.0,T*34\r\n\x00' — ('could not parse data', '$GPHDT,1.0,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.9,T*3C\r\n\x00' — ('could not parse data', '$GPHDT,0.9,T*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.8,T*3D\r\n\x00' — ('could not parse data', '$GPHDT,0.8,T*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.7,T*32\r\n\x00' — ('could not parse data', '$GPHDT,0.7,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.6,T*33\r\n\x00' — ('could not parse data', '$GPHDT,0.6,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.5,T*30\r\n\x00' — ('could not parse data', '$GPHDT,0.5,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.4,T*31\r\n\x00' — ('could not parse data', '$GPHDT,0.4,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.3,T*36\r\n\x00' — ('could not parse data', '$GPHDT,0.3,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.2,T*37\r\n\x00' — ('could not parse data', '$GPHDT,0.2,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.1,T*34\r\n\x00' — ('could not parse data', '$GPHDT,0.1,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.0,T*35\r\n\x00' — ('could not parse data', '$GPHDT,0.0,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.2,T*37\r\n\x00' — ('could not parse data', '$GPHDT,0.2,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.5,T*30\r\n\x00' — ('could not parse data', '$GPHDT,0.5,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,0.8,T*3D\r\n\x00' — ('could not parse data', '$GPHDT,0.8,T*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.2,T*36\r\n\x00' — ('could not parse data', '$GPHDT,1.2,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.5,T*31\r\n\x00' — ('could not parse data', '$GPHDT,1.5,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,1.9,T*3D\r\n\x00' — ('could not parse data', '$GPHDT,1.9,T*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.2,T*35\r\n\x00' — ('could not parse data', '$GPHDT,2.2,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.6,T*31\r\n\x00' — ('could not parse data', '$GPHDT,2.6,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,2.9,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,2.9,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.3,T*35\r\n\x00' — ('could not parse data', '$GPHDT,3.3,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.7,T*31\r\n\x00' — ('could not parse data', '$GPHDT,3.7,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.0,T*31\r\n\x00' — ('could not parse data', '$GPHDT,4.0,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.4,T*35\r\n\x00' — ('could not parse data', '$GPHDT,4.4,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.8,T*39\r\n\x00' — ('could not parse data', '$GPHDT,4.8,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.1,T*31\r\n\x00' — ('could not parse data', '$GPHDT,5.1,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.5,T*35\r\n\x00' — ('could not parse data', '$GPHDT,5.5,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.9,T*39\r\n\x00' — ('could not parse data', '$GPHDT,5.9,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.3,T*30\r\n\x00' — ('could not parse data', '$GPHDT,6.3,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.7,T*34\r\n\x00' — ('could not parse data', '$GPHDT,6.7,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,0.3,M*36\r\n\x00' — ('could not parse data', '$GPHDM,0.3,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.1,T*33\r\n\x00' — ('could not parse data', '$GPHDT,7.1,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.5,T*37\r\n\x00' — ('could not parse data', '$GPHDT,7.5,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,1.3,M*37\r\n\x00' — ('could not parse data', '$GPHDM,1.3,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.9,T*3B\r\n\x00' — ('could not parse data', '$GPHDT,7.9,T*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.4,T*39\r\n\x00' — ('could not parse data', '$GPHDT,8.4,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.8,T*35\r\n\x00' — ('could not parse data', '$GPHDT,8.8,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,2.4,M*33\r\n\x00' — ('could not parse data', '$GPHDM,2.4,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.2,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,9.2,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.6,T*3A\r\n\x00' — ('could not parse data', '$GPHDT,9.6,T*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.5,M*33\r\n\x00' — ('could not parse data', '$GPHDM,3.5,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.6,M*37\r\n\x00' — ('could not parse data', '$GPHDM,4.6,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.7,M*37\r\n\x00' — ('could not parse data', '$GPHDM,5.7,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.9,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,7.9,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,9.0,M*3C\r\n\x00' — ('could not parse data', '$GPHDM,9.0,M*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDM,9.8,M*34\r\n\x00' — ('could not parse data', '$GPHDM,9.8,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,9.4,M*38\r\n\x00' — ('could not parse data', '$GPHDM,9.4,M*38\r\n\x00')
# [WARN] Could not parse: '$GPHDM,9.2,M*3E\r\n\x00' — ('could not parse data', '$GPHDM,9.2,M*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.9,M*34\r\n\x00' — ('could not parse data', '$GPHDM,8.9,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.8,M*35\r\n\x00' — ('could not parse data', '$GPHDM,8.8,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.6,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,8.6,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.5,M*38\r\n\x00' — ('could not parse data', '$GPHDM,8.5,M*38\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.4,M*39\r\n\x00' — ('could not parse data', '$GPHDM,8.4,M*39\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.3,M*3E\r\n\x00' — ('could not parse data', '$GPHDM,8.3,M*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.2,M*3F\r\n\x00' — ('could not parse data', '$GPHDM,8.2,M*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.1,M*3C\r\n\x00' — ('could not parse data', '$GPHDM,8.1,M*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.9,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,7.9,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.8,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,7.8,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.5,M*37\r\n\x00' — ('could not parse data', '$GPHDM,7.5,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.4,M*36\r\n\x00' — ('could not parse data', '$GPHDM,7.4,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.3,M*31\r\n\x00' — ('could not parse data', '$GPHDM,7.3,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.2,M*30\r\n\x00' — ('could not parse data', '$GPHDM,7.2,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.1,M*33\r\n\x00' — ('could not parse data', '$GPHDM,7.1,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.0,M*32\r\n\x00' — ('could not parse data', '$GPHDM,7.0,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.0,M*32\r\n\x00' — ('could not parse data', '$GPHDM,7.0,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.9,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,6.9,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.8,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,6.8,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.8,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,6.8,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.6,M*35\r\n\x00' — ('could not parse data', '$GPHDM,6.6,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.5,M*36\r\n\x00' — ('could not parse data', '$GPHDM,6.5,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.4,M*37\r\n\x00' — ('could not parse data', '$GPHDM,6.4,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.3,M*30\r\n\x00' — ('could not parse data', '$GPHDM,6.3,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.2,M*31\r\n\x00' — ('could not parse data', '$GPHDM,6.2,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.1,M*32\r\n\x00' — ('could not parse data', '$GPHDM,6.1,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.9,M*39\r\n\x00' — ('could not parse data', '$GPHDM,5.9,M*39\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.8,M*38\r\n\x00' — ('could not parse data', '$GPHDM,5.8,M*38\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.6,M*36\r\n\x00' — ('could not parse data', '$GPHDM,5.6,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.4,M*34\r\n\x00' — ('could not parse data', '$GPHDM,5.4,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.2,M*32\r\n\x00' — ('could not parse data', '$GPHDM,5.2,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.0,M*30\r\n\x00' — ('could not parse data', '$GPHDM,5.0,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.7,M*36\r\n\x00' — ('could not parse data', '$GPHDM,4.7,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.4,M*35\r\n\x00' — ('could not parse data', '$GPHDM,4.4,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.1,M*30\r\n\x00' — ('could not parse data', '$GPHDM,4.1,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.8,M*3E\r\n\x00' — ('could not parse data', '$GPHDM,3.8,M*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.5,M*33\r\n\x00' — ('could not parse data', '$GPHDM,3.5,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.8,T*34\r\n\x00' — ('could not parse data', '$GPHDT,9.8,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.7,T*3B\r\n\x00' — ('could not parse data', '$GPHDT,9.7,T*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.5,T*39\r\n\x00' — ('could not parse data', '$GPHDT,9.5,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.1,M*37\r\n\x00' — ('could not parse data', '$GPHDM,3.1,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.4,T*38\r\n\x00' — ('could not parse data', '$GPHDT,9.4,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.2,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,9.2,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDM,2.7,M*30\r\n\x00' — ('could not parse data', '$GPHDM,2.7,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,9.0,T*3C\r\n\x00' — ('could not parse data', '$GPHDT,9.0,T*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.9,T*34\r\n\x00' — ('could not parse data', '$GPHDT,8.9,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.7,T*3A\r\n\x00' — ('could not parse data', '$GPHDT,8.7,T*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,2.3,M*34\r\n\x00' — ('could not parse data', '$GPHDM,2.3,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.5,T*38\r\n\x00' — ('could not parse data', '$GPHDT,8.5,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.4,T*39\r\n\x00' — ('could not parse data', '$GPHDT,8.4,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDM,1.9,M*3D\r\n\x00' — ('could not parse data', '$GPHDM,1.9,M*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.2,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,8.2,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,8.0,T*3D\r\n\x00' — ('could not parse data', '$GPHDT,8.0,T*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.8,T*3A\r\n\x00' — ('could not parse data', '$GPHDT,7.8,T*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,1.5,M*31\r\n\x00' — ('could not parse data', '$GPHDM,1.5,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.7,T*35\r\n\x00' — ('could not parse data', '$GPHDT,7.7,T*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.5,T*37\r\n\x00' — ('could not parse data', '$GPHDT,7.5,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,1.1,M*35\r\n\x00' — ('could not parse data', '$GPHDM,1.1,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.4,T*36\r\n\x00' — ('could not parse data', '$GPHDT,7.4,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.2,T*30\r\n\x00' — ('could not parse data', '$GPHDT,7.2,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,7.0,T*32\r\n\x00' — ('could not parse data', '$GPHDT,7.0,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,0.6,M*33\r\n\x00' — ('could not parse data', '$GPHDM,0.6,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.9,T*3A\r\n\x00' — ('could not parse data', '$GPHDT,6.9,T*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.7,T*34\r\n\x00' — ('could not parse data', '$GPHDT,6.7,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,0.2,M*37\r\n\x00' — ('could not parse data', '$GPHDM,0.2,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.5,T*36\r\n\x00' — ('could not parse data', '$GPHDT,6.5,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.4,T*37\r\n\x00' — ('could not parse data', '$GPHDT,6.4,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.2,T*31\r\n\x00' — ('could not parse data', '$GPHDT,6.2,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,6.0,T*33\r\n\x00' — ('could not parse data', '$GPHDT,6.0,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.9,T*39\r\n\x00' — ('could not parse data', '$GPHDT,5.9,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.7,T*37\r\n\x00' — ('could not parse data', '$GPHDT,5.7,T*37\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.6,T*36\r\n\x00' — ('could not parse data', '$GPHDT,5.6,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.4,T*34\r\n\x00' — ('could not parse data', '$GPHDT,5.4,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.3,T*33\r\n\x00' — ('could not parse data', '$GPHDT,5.3,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.2,T*32\r\n\x00' — ('could not parse data', '$GPHDT,5.2,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,5.0,T*30\r\n\x00' — ('could not parse data', '$GPHDT,5.0,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.9,T*38\r\n\x00' — ('could not parse data', '$GPHDT,4.9,T*38\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.8,T*39\r\n\x00' — ('could not parse data', '$GPHDT,4.8,T*39\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.7,T*36\r\n\x00' — ('could not parse data', '$GPHDT,4.7,T*36\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.5,T*34\r\n\x00' — ('could not parse data', '$GPHDT,4.5,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.5,T*34\r\n\x00' — ('could not parse data', '$GPHDT,4.5,T*34\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.3,T*32\r\n\x00' — ('could not parse data', '$GPHDT,4.3,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.3,T*32\r\n\x00' — ('could not parse data', '$GPHDT,4.3,T*32\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.2,T*33\r\n\x00' — ('could not parse data', '$GPHDT,4.2,T*33\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.1,T*30\r\n\x00' — ('could not parse data', '$GPHDT,4.1,T*30\r\n\x00')
# [WARN] Could not parse: '$GPHDT,4.0,T*31\r\n\x00' — ('could not parse data', '$GPHDT,4.0,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.9,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,3.9,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.9,T*3F\r\n\x00' — ('could not parse data', '$GPHDT,3.9,T*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.8,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,3.8,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.8,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,3.8,T*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.7,T*31\r\n\x00' — ('could not parse data', '$GPHDT,3.7,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.7,T*31\r\n\x00' — ('could not parse data', '$GPHDT,3.7,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.7,T*31\r\n\x00' — ('could not parse data', '$GPHDT,3.7,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.7,T*31\r\n\x00' — ('could not parse data', '$GPHDT,3.7,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.7,T*31\r\n\x00' — ('could not parse data', '$GPHDT,3.7,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.7,T*31\r\n\x00' — ('could not parse data', '$GPHDT,3.7,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.7,T*31\r\n\x00' — ('could not parse data', '$GPHDT,3.7,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.7,T*31\r\n\x00' — ('could not parse data', '$GPHDT,3.7,T*31\r\n\x00')
# [WARN] Could not parse: '$GPHDT,3.8,T*3E\r\n\x00' — ('could not parse data', '$GPHDT,3.8,T*3E\r\n\x00')
# ...
# [WARN] Could not parse: '$GPHDM,3.8,M*3E\r\n\x00' — ('could not parse data', '$GPHDM,3.8,M*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.9,M*3F\r\n\x00' — ('could not parse data', '$GPHDM,3.9,M*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDM,3.9,M*3F\r\n\x00' — ('could not parse data', '$GPHDM,3.9,M*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.0,M*31\r\n\x00' — ('could not parse data', '$GPHDM,4.0,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.1,M*30\r\n\x00' — ('could not parse data', '$GPHDM,4.1,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.1,M*30\r\n\x00' — ('could not parse data', '$GPHDM,4.1,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.2,M*33\r\n\x00' — ('could not parse data', '$GPHDM,4.2,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.3,M*32\r\n\x00' — ('could not parse data', '$GPHDM,4.3,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.3,M*32\r\n\x00' — ('could not parse data', '$GPHDM,4.3,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.3,M*32\r\n\x00' — ('could not parse data', '$GPHDM,4.3,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.4,M*35\r\n\x00' — ('could not parse data', '$GPHDM,4.4,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.5,M*34\r\n\x00' — ('could not parse data', '$GPHDM,4.5,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.5,M*34\r\n\x00' — ('could not parse data', '$GPHDM,4.5,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.6,M*37\r\n\x00' — ('could not parse data', '$GPHDM,4.6,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.7,M*36\r\n\x00' — ('could not parse data', '$GPHDM,4.7,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.7,M*36\r\n\x00' — ('could not parse data', '$GPHDM,4.7,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.8,M*39\r\n\x00' — ('could not parse data', '$GPHDM,4.8,M*39\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.8,M*39\r\n\x00' — ('could not parse data', '$GPHDM,4.8,M*39\r\n\x00')
# [WARN] Could not parse: '$GPHDM,4.9,M*38\r\n\x00' — ('could not parse data', '$GPHDM,4.9,M*38\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.0,M*30\r\n\x00' — ('could not parse data', '$GPHDM,5.0,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.0,M*30\r\n\x00' — ('could not parse data', '$GPHDM,5.0,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.0,M*30\r\n\x00' — ('could not parse data', '$GPHDM,5.0,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.0,M*30\r\n\x00' — ('could not parse data', '$GPHDM,5.0,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.0,M*30\r\n\x00' — ('could not parse data', '$GPHDM,5.0,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.0,M*30\r\n\x00' — ('could not parse data', '$GPHDM,5.0,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.1,M*31\r\n\x00' — ('could not parse data', '$GPHDM,5.1,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.2,M*32\r\n\x00' — ('could not parse data', '$GPHDM,5.2,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.2,M*32\r\n\x00' — ('could not parse data', '$GPHDM,5.2,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.3,M*33\r\n\x00' — ('could not parse data', '$GPHDM,5.3,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.4,M*34\r\n\x00' — ('could not parse data', '$GPHDM,5.4,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.5,M*35\r\n\x00' — ('could not parse data', '$GPHDM,5.5,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.5,M*35\r\n\x00' — ('could not parse data', '$GPHDM,5.5,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.5,M*35\r\n\x00' — ('could not parse data', '$GPHDM,5.5,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.5,M*35\r\n\x00' — ('could not parse data', '$GPHDM,5.5,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.6,M*36\r\n\x00' — ('could not parse data', '$GPHDM,5.6,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.7,M*37\r\n\x00' — ('could not parse data', '$GPHDM,5.7,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.7,M*37\r\n\x00' — ('could not parse data', '$GPHDM,5.7,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.8,M*38\r\n\x00' — ('could not parse data', '$GPHDM,5.8,M*38\r\n\x00')
# [WARN] Could not parse: '$GPHDM,5.9,M*39\r\n\x00' — ('could not parse data', '$GPHDM,5.9,M*39\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.0,M*33\r\n\x00' — ('could not parse data', '$GPHDM,6.0,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.1,M*32\r\n\x00' — ('could not parse data', '$GPHDM,6.1,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.2,M*31\r\n\x00' — ('could not parse data', '$GPHDM,6.2,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.3,M*30\r\n\x00' — ('could not parse data', '$GPHDM,6.3,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.4,M*37\r\n\x00' — ('could not parse data', '$GPHDM,6.4,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.6,M*35\r\n\x00' — ('could not parse data', '$GPHDM,6.6,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.6,M*35\r\n\x00' — ('could not parse data', '$GPHDM,6.6,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.6,M*35\r\n\x00' — ('could not parse data', '$GPHDM,6.6,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.6,M*35\r\n\x00' — ('could not parse data', '$GPHDM,6.6,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.6,M*35\r\n\x00' — ('could not parse data', '$GPHDM,6.6,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.5,M*36\r\n\x00' — ('could not parse data', '$GPHDM,6.5,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.5,M*36\r\n\x00' — ('could not parse data', '$GPHDM,6.5,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.5,M*36\r\n\x00' — ('could not parse data', '$GPHDM,6.5,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.5,M*36\r\n\x00' — ('could not parse data', '$GPHDM,6.5,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.5,M*36\r\n\x00' — ('could not parse data', '$GPHDM,6.5,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.5,M*36\r\n\x00' — ('could not parse data', '$GPHDM,6.5,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.5,M*36\r\n\x00' — ('could not parse data', '$GPHDM,6.5,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.6,M*35\r\n\x00' — ('could not parse data', '$GPHDM,6.6,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.6,M*35\r\n\x00' — ('could not parse data', '$GPHDM,6.6,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.7,M*34\r\n\x00' — ('could not parse data', '$GPHDM,6.7,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.8,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,6.8,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.8,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,6.8,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.8,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,6.8,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.8,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,6.8,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.8,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,6.8,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.8,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,6.8,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.9,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,6.9,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.9,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,6.9,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.9,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,6.9,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,6.9,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,6.9,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.0,M*32\r\n\x00' — ('could not parse data', '$GPHDM,7.0,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.0,M*32\r\n\x00' — ('could not parse data', '$GPHDM,7.0,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.0,M*32\r\n\x00' — ('could not parse data', '$GPHDM,7.0,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.0,M*32\r\n\x00' — ('could not parse data', '$GPHDM,7.0,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.0,M*32\r\n\x00' — ('could not parse data', '$GPHDM,7.0,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.0,M*32\r\n\x00' — ('could not parse data', '$GPHDM,7.0,M*32\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.1,M*33\r\n\x00' — ('could not parse data', '$GPHDM,7.1,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.1,M*33\r\n\x00' — ('could not parse data', '$GPHDM,7.1,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.1,M*33\r\n\x00' — ('could not parse data', '$GPHDM,7.1,M*33\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.2,M*30\r\n\x00' — ('could not parse data', '$GPHDM,7.2,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.2,M*30\r\n\x00' — ('could not parse data', '$GPHDM,7.2,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.2,M*30\r\n\x00' — ('could not parse data', '$GPHDM,7.2,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.2,M*30\r\n\x00' — ('could not parse data', '$GPHDM,7.2,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.2,M*30\r\n\x00' — ('could not parse data', '$GPHDM,7.2,M*30\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.3,M*31\r\n\x00' — ('could not parse data', '$GPHDM,7.3,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.3,M*31\r\n\x00' — ('could not parse data', '$GPHDM,7.3,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.3,M*31\r\n\x00' — ('could not parse data', '$GPHDM,7.3,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.3,M*31\r\n\x00' — ('could not parse data', '$GPHDM,7.3,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.3,M*31\r\n\x00' — ('could not parse data', '$GPHDM,7.3,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.3,M*31\r\n\x00' — ('could not parse data', '$GPHDM,7.3,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.3,M*31\r\n\x00' — ('could not parse data', '$GPHDM,7.3,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.3,M*31\r\n\x00' — ('could not parse data', '$GPHDM,7.3,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.3,M*31\r\n\x00' — ('could not parse data', '$GPHDM,7.3,M*31\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.4,M*36\r\n\x00' — ('could not parse data', '$GPHDM,7.4,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.4,M*36\r\n\x00' — ('could not parse data', '$GPHDM,7.4,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.4,M*36\r\n\x00' — ('could not parse data', '$GPHDM,7.4,M*36\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.5,M*37\r\n\x00' — ('could not parse data', '$GPHDM,7.5,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.5,M*37\r\n\x00' — ('could not parse data', '$GPHDM,7.5,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.5,M*37\r\n\x00' — ('could not parse data', '$GPHDM,7.5,M*37\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.6,M*34\r\n\x00' — ('could not parse data', '$GPHDM,7.6,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.6,M*34\r\n\x00' — ('could not parse data', '$GPHDM,7.6,M*34\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.7,M*35\r\n\x00' — ('could not parse data', '$GPHDM,7.7,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.8,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,7.8,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.8,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,7.8,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.8,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,7.8,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.8,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,7.8,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.8,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,7.8,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.8,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,7.8,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.8,M*3A\r\n\x00' — ('could not parse data', '$GPHDM,7.8,M*3A\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.9,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,7.9,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,7.9,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,7.9,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.0,M*3D\r\n\x00' — ('could not parse data', '$GPHDM,8.0,M*3D\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.2,M*3F\r\n\x00' — ('could not parse data', '$GPHDM,8.2,M*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.4,M*39\r\n\x00' — ('could not parse data', '$GPHDM,8.4,M*39\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.6,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,8.6,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,8.8,M*35\r\n\x00' — ('could not parse data', '$GPHDM,8.8,M*35\r\n\x00')
# [WARN] Could not parse: '$GPHDM,9.0,M*3C\r\n\x00' — ('could not parse data', '$GPHDM,9.0,M*3C\r\n\x00')
# [WARN] Could not parse: '$GPHDM,9.2,M*3E\r\n\x00' — ('could not parse data', '$GPHDM,9.2,M*3E\r\n\x00')
# [WARN] Could not parse: '$GPHDM,9.3,M*3F\r\n\x00' — ('could not parse data', '$GPHDM,9.3,M*3F\r\n\x00')
# [WARN] Could not parse: '$GPHDM,9.5,M*39\r\n\x00' — ('could not parse data', '$GPHDM,9.5,M*39\r\n\x00')
# [WARN] Could not parse: '$GPHDM,9.7,M*3B\r\n\x00' — ('could not parse data', '$GPHDM,9.7,M*3B\r\n\x00')
# [WARN] Could not parse: '$GPHDM,9.8,M*34\r\n\x00' — ('could not parse data', '$GPHDM,9.8,M*34\r\n\x00')
# ✓ Processed 188036 track updates
# ✓ Results written to tracks_output.json
#
# ✓ Processed 188036 track updates

# %%
from scapy.all import rdpcap, UDP

def inspect_pcap(filepath):
    packets = rdpcap(filepath)
    sentence_types = {}

    for packet in packets:
        if UDP in packet:
            try:
                payload = bytes(packet[UDP].payload).decode("ascii").strip()
                if payload.startswith("$"):
                    # Extract just the sentence type e.g. GPRMC, GPHDT
                    talker_and_type = payload[1:].split(",")[0]
                    sentence_types[talker_and_type] = sentence_types.get(talker_and_type, 0) + 1
            except UnicodeDecodeError:
                pass

    print("Sentence types found:")
    for k, v in sorted(sentence_types.items(), key=lambda x: -x[1]):
        print(f"  {k}: {v} packets")

inspect_pcap("kraken_data/multicast_AdvNavData-2026-05-08_07-40-14_capture.pcap")
